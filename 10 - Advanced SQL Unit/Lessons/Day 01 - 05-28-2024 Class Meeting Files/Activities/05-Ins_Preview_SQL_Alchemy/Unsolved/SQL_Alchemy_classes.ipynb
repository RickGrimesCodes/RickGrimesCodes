# %%
# Import the dependencies.
from sqlalchemy import create_engine
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
# Out:
# C:\Users\nolan\AppData\Local\Temp\ipykernel_73504\2858130796.py:5: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
# Create a Dog Class for the table. 
class Dog(Base):
    _tablename_ = 'dog'
    id = Column(Integer, primary_key=True)
    name = Column(String(255))
    color = Column(String(255))
    age = Column(Integer)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Create a Dog Class for the table.
# ----> 2 class Dog(Base):
#       3     _tablename_ = 'dog'
#       4     id = Column(Integer, primary_key=True)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\orm\decl_api.py:196, in DeclarativeMeta.__init__(cls, classname, bases, dict_, **kw)
#     193         cls._sa_registry = reg
#     195 if not cls.__dict__.get("__abstract__", False):
# --> 196     _as_declarative(reg, cls, dict_)
#     197 type.__init__(cls, classname, bases, dict_)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\orm\decl_base.py:244, in _as_declarative(registry, cls, dict_)
#     239 def _as_declarative(
#     240     registry: _RegistryType, cls: Type[Any], dict_: _ClassDict
#     241 ) -> Optional[_MapperConfig]:
#     242     # declarative scans the class for attributes.  no table or mapper
#     243     # args passed separately.
# --> 244     return _MapperConfig.setup_mapping(registry, cls, dict_, None, {})
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\orm\decl_base.py:325, in _MapperConfig.setup_mapping(cls, registry, cls_, dict_, table, mapper_kw)
#     321     return _DeferredMapperConfig(
#     322         registry, cls_, dict_, table, mapper_kw
#     323     )
#     324 else:
# --> 325     return _ClassScanMapperConfig(
#     326         registry, cls_, dict_, table, mapper_kw
#     327     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\orm\decl_base.py:577, in _ClassScanMapperConfig.__init__(self, registry, cls_, dict_, table, mapper_kw)
#     573 self._extract_declared_columns()
#     575 self._setup_table(table)
# --> 577 self._setup_inheriting_columns(mapper_kw)
#     579 self._early_mapping(mapper_kw)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sqlalchemy\orm\decl_base.py:1798, in _ClassScanMapperConfig._setup_inheriting_columns(self, mapper_kw)
#    1791 declared_columns = self.declared_columns
#    1793 if (
#    1794     table is None
#    1795     and self.inherits is None
#    1796     and not _get_immediate_cls_attr(cls, "__no_table__")
#    1797 ):
# -> 1798     raise exc.InvalidRequestError(
#    1799         "Class %r does not have a __table__ or __tablename__ "
#    1800         "specified and does not inherit from an existing "
#    1801         "table-mapped class." % cls
#    1802     )
#    1803 elif self.inherits:
#    1804     inherited_mapper_or_config = _declared_mapping_info(self.inherits)
#
# InvalidRequestError: Class <class '__main__.Dog'> does not have a __table__ or __tablename__ specified and does not inherit from an existing table-mapped class.

# %%
# Create a Cat Class for the table.
class Cat(Base):
    __tablename__ = 'cat'
    id = Column(Integer, primary_key = True)
    name = Column(String(255))
    color = Column(String(255))
    age = Column(Integer)

# %%
# Create a Specific Instance of the Dog and Cat classes
dog = DOg(name="Fido"

# %%
# Create Database Connection

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database

# %%
# Create a Session Object to Connect to DB

# %%
# Add Records to the Appropriate DB

# %%
# Query the Dog table

# %%
# Query the Cat table

# %%
# Uncomment the code below to clear out the db if you don't want duplicates. 
# Base.metadata.drop_all(engine)
