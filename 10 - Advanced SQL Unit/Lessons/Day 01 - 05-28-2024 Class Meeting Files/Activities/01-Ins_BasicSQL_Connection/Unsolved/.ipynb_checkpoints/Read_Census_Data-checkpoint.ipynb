# %%
# Import the dependencies.
from pathlib import Path
from sqlalchemy import create_engine, text

# Create a reference to the file. 
database_path = Path("../Resources/Census_Data.sqlite")

# %%
# Create an engine that can talk to the database
# use the create_engine() function
# for sqlite precompiled databases use:
engine = create_engine(f"sqlite:///{database_path}")

# %%
# Query All Records in the the Database
query = text("SELECT * FROM Census_Data")

with engine.connect() as conn:
    data = conn.execute(query)

for record in data:
    print(record)

# %%
# for postgresql databases:
# engine = create_engine(f"postgresql://username:password@localhost/databaseName")

# we need a database name:
dbName = "05282024DB"

# a user name:
userName = "postgres"

# and a password:
password = "Simmons929717"

engine = create_engine(f"postgresql://{userName}:{password}@localhost/{dbName}")

# %%
# Query All Records in the the Database
query = text("SELECT * FROM Census_Data")
with engine.connect() as conn:
    data = conn.execute(query)
for record in data:
    print(record)
# Out:
# ('HOUSTON, TX', 'HOUSTON', 'TX', 3061887, 1775897, 684416, 11586, 230549, 1368287, 54180, 387082, 62520, 100014, 349920, 138882, 42491, 27737, 633609, 1593803, 122895, 67484, 22637, Decimal('33.43958333'), Decimal('32.55'), Decimal('34.36354167'), Decimal('56206.5'), Decimal('32239.52083'), Decimal('956.7083333'), Decimal('178233.6842'), Decimal('29.77573444'), Decimal('-95.41454828'))
# ('CHICAGO, IL', 'CHICAGO', 'IL', 2702091, 1318869, 843633, 7554, 161478, 785374, 32800, 370569, 50202, 100972, 385664, 178511, 54636, 26956, 588639, 1439118, 173087, 45864, 18209, Decimal('34.52678571'), Decimal('33.79821429'), Decimal('35.14107143'), Decimal('57735.96429'), Decimal('38730.83929'), Decimal('1119.928571'), Decimal('264739.2857'), Decimal('41.86783754'), Decimal('-87.67343993'))
# ...
