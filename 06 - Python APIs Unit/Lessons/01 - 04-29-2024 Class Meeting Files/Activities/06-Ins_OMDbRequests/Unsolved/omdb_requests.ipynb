# %%
import requests
import json
from config import api_key

# %%
# New Dependency! Use this to pretty print the JSON
# https://docs.python.org/3/library/pprint.html
from pprint import pprint

# %%
# Note that the ?t= is a query param for the t-itle of the
# movie we want to search for.
url = "http://www.omdbapi.com/?t="
api_key = "&apikey=" + f853d8f6
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 # Note that the ?t= is a query param for the t-itle of the
#       2 # movie we want to search for.
#       3 url = "http://www.omdbapi.com/?t="
# ----> 4 api_key = "&apikey=" + f853d8f6
#
# NameError: name 'f853d8f6' is not defined

# %%
# Performing a GET request similar to the one we executed
# earlier
# baseUrl + title + apikey
response = requests.get(url + "Friday" + api_key)

# %%
# Converting the response to JSON, and printing the result.
filmData = response.json()
pprint(filmData)
# Out:
# {'Error': 'No API key provided.', 'Response': 'False'}

# %%
# Print a few keys from the response JSON.
# Out:
# Movie was directed by James Cameron.
# Movie was released in United Kingdom, United States.
