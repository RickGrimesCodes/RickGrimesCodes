# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# assign the met database to a variable name
db = mongo['met']

# assign the collection to a variable
artifacts = db['artifacts']

# %%
# Write an aggregation query that counts the number of documents, grouped by "country"
# $group property with criteria
    # use $_id property to tell what key to group by
    # then use the 'count' property, then tell how you will count (Use the $sum property)
query = [{'$group': {'_id': "$country", 'count': { '$sum': 1 }}}]

# %%
# Run the query with the aggregate method and save the results to a variable
# use .aggregate() to perform the count of the number of countries
results = list(artifacts.aggregate(query))

# %%
# Print the number of countries in the result
print("Number of countries in result: ", len(results))
# Out:
# Number of countries in result:  80

# %%
# Print the first 10 results
pprint(results[0:10])
# Out:
# [{'_id': 'Colombia or Ecuador', 'count': 4},
#  {'_id': 'Peru', 'count': 245},
#  {'_id': 'Madagascar', 'count': 3},
#  {'_id': 'Costa Rica', 'count': 20},
#  {'_id': 'Tanzania', 'count': 2},
#  {'_id': 'Costa Rica or Panama', 'count': 11},
#  {'_id': 'Bolivia', 'count': 6},
#  {'_id': 'India', 'count': 3},
#  {'_id': 'Bolivia or Peru', 'count': 3},
#  {'_id': 'Rwanda', 'count': 1}]

# %%
# Convert mongo result to Pandas DataFrame
resultsDF = pd.DataFrame(results[0:10])
resultsDF
# Out:
#                     _id  count
# 0   Colombia or Ecuador      4
# 1                  Peru    245
# 2            Madagascar      3
# 3            Costa Rica     20
# 4              Tanzania      2
# 5  Costa Rica or Panama     11
# 6               Bolivia      6
# 7                 India      3
# 8       Bolivia or Peru      3
# 9                Rwanda      1

# %% [markdown]
# Data Source: [The Metropolitan Museum of Art](https://www.metmuseum.org/) (2022). The Metropolitan Museum of Art Collection API https://metmuseum.github.io/. Licensed under the [Creative Commons 0 License](https://creativecommons.org/publicdomain/zero/1.0/).<br />
# Accessed Oct 3, 2022. Data collected from departmentId=5 ("Arts of Africa, Oceania, and the Americas") and search string "animal".
