# %% [markdown]
# # Introduction to Mongo

# %% [markdown]
# Import the data first:
#
# ```shell
# mongoimport --type csv -d petsitly_marketing -c customer_list --headerline --drop customer_database.csv
# ```

# %%
from pymongo import MongoClient

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'fruits_db', 'local', 'petsitly_marketing']

# %%
# assign the database to a variable name
db = mongo.petsitly_marketing # or db = mongo['petsitly_marketing']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['customer_list']

# %%
# review a document in the customer_list collection
db.customer_list.find_one()
# Out:
# {'_id': ObjectId('666b7b9c317ea75f4158e281'),
#  'Customer_First': 'Tyrese',
#  'Customer_Last': 'Buckridge',
#  'Address': '2533 Ford Views',
#  'Email': 'wcastro@yahoo.com',
#  '2021_Visits': 27,
#  '2021_Total_Spend': 465.75,
#  'Pet_Type': 'bird'}

# %%
# assign the collection to a variable
db.customer_list.find_one()
# Out:
# {'_id': ObjectId('666b7b9c317ea75f4158e281'),
#  'Customer_First': 'Tyrese',
#  'Customer_Last': 'Buckridge',
#  'Address': '2533 Ford Views',
#  'Email': 'wcastro@yahoo.com',
#  '2021_Visits': 27,
#  '2021_Total_Spend': 465.75,
#  'Pet_Type': 'bird'}

# %%
# insert a new customer
customer_list = db['customer_list']
new_customer = {'_id':3, 'Customer_First': 'Data', 'Customer_Last': 'Viz',
                'Address': '55882 Valley Fields Dr', 'Email': 'dataviz@bootcamp.edu',
                '2021_Visits': 75, '2021_Total_Spend': 2017.75, 'Pet_Type': 'cat'}
customer_list.insert_one(new_customer)
# Out:
# InsertOneResult(3, acknowledged=True)

# %%
# Filter results by name
customer_list = db['customer_list']

# %%
# Find all the customers with hamsters
query = {'Customer_First': 'Data'} #     search sting that finds customers with the first name 'Data'
results = customer_list.find(query)
for result in results:
    print(result)
# Out:
# {'_id': 3, 'Customer_First': 'Data', 'Customer_Last': 'Viz', 'Address': '55882 Valley Fields Dr', 'Email': 'dataviz@bootcamp.edu', '2021_Visits': 75, '2021_Total_Spend': 2017.75, 'Pet_Type': 'cat'}

# %%
# Delete all the customers who have hamsters
customer_list.delete_many(query)
results = customer_list.find(query)
for result in results:
    print(result)

# %%
# Delete a collection
db.drop_collection('customer_list')
db.list_collection_names()
# Out:
# []

# %%
# Delete the database
mongo.drop_database('petsitly_marketing')
mongo.list_database_names
# Out:
# <bound method MongoClient.list_database_names of MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)>
